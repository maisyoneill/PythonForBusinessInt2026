# %%
#Tasks

# %%
##Task 1

transactions = [
    {"id": 1, "product": "Laptop", "price": 1200, "quantity": 2, "region": "EU"},
    {"id": 2, "product": "Phone", "price": 800, "quantity": -1, "region": "US"},
    {"id": 3, "product": "Tablet", "price": 0, "quantity": 5, "region": "EU"},
    {"id": 4, "product": "Monitor", "price": 350, "quantity": 3, "region": "US"},
    {"id": 5, "product": "Laptop", "price": 1200, "quantity": 1, "region": "EU"},
    {"id": 6, "product": "Keyboard", "price": 75, "quantity": 10, "region": "APAC"},
]



for i in transactions:
    if int("price") > 0 and quantity >= 0 :
        total = i["price"] * i["quantity"]

print(total)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 15
#       3 transactions = [
#       4     {"id": 1, "product": "Laptop", "price": 1200, "quantity": 2, "region": "EU"},
#       5     {"id": 2, "product": "Phone", "price": 800, "quantity": -1, "region": "US"},
#    (...)      9     {"id": 6, "product": "Keyboard", "price": 75, "quantity": 10, "region": "APAC"},
#      10 ]
#      14 for i in transactions:
# ---> 15     if int("price") > 0 and quantity >= 0 :
#      16         total = i["price"] * i["quantity"]
#      18 print(total)
#
# ValueError: invalid literal for int() with base 10: 'price'

# %%
##Task 2
from statistics import mean
sales = [1200, 980, 1540, 870, 2010, 1650, 1300, 1100, 950, 1780, 2200, 1430, 1600, 1900]

total = sum(sales)
average = mean(sales)

best_day = 0
max_sales=0
for i, value in enumerate(sales, start=1):
    if value > max_sales:
        max_sales = value
        best_day = i

worst_day = 0
min_sales= float('inf')
for i, value in enumerate(sales, start=1):
    if value < min_sales:
        min_sales = value
        worst_day = i

above_average_count = 0
for s in sales:
    if s > mean(sales):
        above_average_count += 1

summarise_sales = dict({1: total, 2: average, 3:best_day, 4:worst_day, 5:above_average_count})

print(summarise_sales)
# Out:
# {1: 20510, 2: 1465, 3: 11, 4: 4, 5: 7}
